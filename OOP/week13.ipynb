# %%
class Villager:
    VillageName = "AliAbad"
    CLimate = "rainy"
    Population = 0
    def __init__(self,VillagerName,VillagerRole):
        self.role = VillagerRole
        self.name = VillagerName
        Villager.Population += 1

    def GoWrok(self):
        print(f"{self.name} : Im going to work : {self.role}")

# %%
person1 = Villager("Mahdi","Programmer")

# %%
person3 = Villager("Abbas","Judge")
person2 = Villager("Adnan","Lawer")

# %%
person2.GoWrok()
# Out:
# Adnan : Im going to work : Lawer

# %% [markdown]
# RELATIONS BETWEEN CALSESS

# %% [markdown]
# ASSOSIATION

# %%
class Villager:
    VillageName = "AliAbad"
    CLimate = "rainy"
    Population = 0
    def __init__(self,VillagerName,VillagerRole):
        self.role = VillagerRole
        self.name = VillagerName
        Villager.Population += 1

    def GoWrok(self):
        print(f"{self.name} : Im going to work : {self.role}")

    def meet(self,person):
        print(f"{self.name} meeted {person.name}")

# %%
person1.meet(person2)
# Out:
# Mahdi meeted Adnan

# %% [markdown]
# COMPOSITION

# %%
class Heart():
    def __init__(self,name):
        self.status = "active"
        print(f"{name} : my heart is {self.status}")

# %%
class Villager:
    VillageName = "AliAbad"
    CLimate = "rainy"
    Population = 0
    def __init__(self,VillagerName,VillagerRole):
        self.role = VillagerRole
        self.name = VillagerName
        self.heart = Heart(self.name)
        Villager.Population += 1

    def GoWrok(self):
        print(f"{self.name} : Im going to work : {self.role}")

    def meet(self,person):
        print(f"{self.name} meeted {person.name}")

# %%
person4 = Villager("vahid","celergyman")
# Out:
# vahid : my heart is active

# %% [markdown]
# AGGREGATION

# %%
class Tool():
    def __init__(self,name,owner):
        self.ToolName = name
        self.owner = owner

# %%
class Villager:
    VillageName = "AliAbad"
    CLimate = "rainy"
    Population = 0
    def __init__(self,VillagerName,VillagerRole):
        self.role = VillagerRole
        self.name = VillagerName
        self.heart = Heart(self.name)
        self.tool = None
        Villager.Population += 1

    def GoWrok(self):
        print(f"{self.name} : Im going to work : {self.role}")

    def meet(self,person):
        print(f"{self.name} meeted {person.name}")

# %%
person5 = Villager("nima","rider")
tool1 = Tool("cycle",person5.name)
person5.tool = tool1
person5.tool.ToolName

del person5
print(f"{tool1.ToolName}")
# Out:
# nima : my heart is active
# cycle

# %% [markdown]
# ENCAPSULATION

# %%
class Villager:
    VillageName = "AliAbad"
    CLimate = "rainy"
    Population = 0
    def __init__(self,VillagerName,VillagerRole):
        self.role = VillagerRole
        self.name = VillagerName
        self.heart = Heart(self.name)
        self.tool = None
        self.saving = 0
        Villager.Population += 1

    def GoWrok(self):
        print(f"{self.name} : Im going to work : {self.role}")

    def meet(self,person):
        print(f"{self.name} meeted {person.name}")

# %%
person6 = Villager("Amoo","Student")
person6.saving = 70000
person6.saving
# Out:
# Amoo : my heart is active
# 70000

# %%
class Villager:
    VillageName = "AliAbad"
    CLimate = "rainy"
    Population = 0
    def __init__(self,VillagerName,VillagerRole):
        self.role = VillagerRole
        self.name = VillagerName
        self.heart = Heart(self.name)
        self.tool = None
        self.__saving = 0
        Villager.Population += 1

    def GoWrok(self):
        print(f"{self.name} : Im going to work : {self.role}")

    def meet(self,person):
        print(f"{self.name} meeted {person.name}")

    def money(self):
        print(f"your mony is {self.__saving}")

    def save(self,price):
        self.__saving = self.__saving + price

# %%
person7 = Villager("mostafa","Student")
person7.save(3000)
person7.money()
# Out:
# mostafa : my heart is active
# your mony is 3000

# %% [markdown]
# INHERITAED

# %%
class Farmer(Villager):
        job = "farmer"
        def __init__(self, VillagerName):
                super().__init__(VillagerName,Farmer.job)

# %%
person9 = Farmer("mohamad")
person9.GoWrok()
person9.job
# Out:
# mohamad : my heart is active
# mohamad : Im going to work : farmer
# 'farmer'
